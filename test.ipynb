# %%
import pandas as pd

# %%
pd.read_parquet("./center_east_Mousq_2_Filttered_with_Adhan_All_2.parquet").head(2)
# Out:
#                    METER_ID    READING_DATETIME  ACTIVE_IMP_POWER   Fajr  \
# 0          KFM2020766054481 2024-05-01 09:00:00             842.0  03:58
# 1          AES2020896469563 2024-05-01 04:30:00               0.0  04:00
# 2          KFM2020766128709 2024-05-01 00:30:00             172.0  03:57
# 3          KFM2020766128709 2024-05-01 01:00:00             174.0  03:57
# 4          KFM2020766128709 2024-05-01 00:00:00             170.0  03:57
# ...                     ...                 ...               ...    ...
# 178828022  AES2120896551632 2024-08-31 08:30:00              97.0  04:35
# 178828023  AES2120896551632 2024-08-31 04:30:00             313.0  04:35
# 178828024  AES2120896551632 2024-08-31 05:30:00            1172.0  04:35
# 178828025  AES2120896551632 2024-08-31 04:00:00             313.0  04:35
# 178828026  AES2120896551632 2024-08-31 09:30:00              97.0  04:35
#
#            Dhuhr   Isha
# 0          11:51  19:52
# 1          12:07  20:16
# ...
